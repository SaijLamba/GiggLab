# %%
from ipynb.fs.full.ScPipelineProto import *
import cfad
from pathlib import Path
import math

# %%
def split_channels_by_region(df):
    channels = {}
    unique_regions = df["acronym"].unique()

    for region in unique_regions:
        grouped = df.groupby("acronym")
        region_df = grouped.get_group(region)

        channel_ids = region_df["channel_id"].values

        channels.update({region: channel_ids})
    return channels

# %%
results = []
Group = [None, "Vehicle", "Vehicle", "Psilocybin", "Vehicle", "Psilocybin", "Vehicle", "Psilocybin", "Psilocybin", "Vehicle"]
for mouse in [2, 3, 4, 5, 7, 8, 9]:
    print(f"mouse = {mouse}")
    trial_types = ["Flash", "Loom", "EveryLoom"]
    experiments = ["extinction", "renewal"]
    for trial_type in trial_types:
        for experiment in experiments:
            if experiment == "extinction":
                mean_path = rf"Z:\Saij\Data\extinction\Mouse{mouse}\data\meanLFP{trial_type}\meanLFP.dat"
                experiment = "Extinction"
            else:
                mean_path = rf"Z:\Saij\Data\renewal\Mouse{mouse}\data\meanLFP{trial_type}\meanLFP.dat"
                experiment = "Retention"
            ccf_path = rf"Z:\Saij\ccf_channels\Mouse {mouse}.csv"
            df = pd.read_csv(ccf_path)
            
            region_channels = split_channels_by_region(df)
            
            mean_clean, mean_meta = load_scaled_lfp_from_dat(mean_path)
            
            fs = mean_meta
            if trial_type == "EveryLoom":
                window = (-0.1, 0.7)
                stims = [0]
                post = 0.5
            else:
                window = (-0.1, 5)
                post = 1
                if trial_type == "Flash":
                    stims = [0, 2.94]
                elif trial_type == "Loom":
                    stims = [0, 1.47, 2.94]

            offset = np.abs(window[0])
            stims_offset = np.array(stims) + offset
            stims_samples = stims_offset * fs
            
            
        
            for region in region_channels:
                channels = region_channels[region]
                roi = mean_clean[channels]
                #Bad channel detection in mouse 8 has ommitted all data from Void, not the end of the world
                #but to make the loop work this exclusion is hard coded
                #can make the loop more sophisticated and automated but i'd rather it be hard coded and break
                #just so i can be privy to these details when it does break
                if region == "Void" and mouse == 8:
                    continue
                for n, stim in enumerate(stims_samples):
                    if trial_type == "Loom":
                        stim_type = f"Loom {n + 1}"
                    elif trial_type == "Flash":
                        if n == 0:
                            stim_type = "Flash On"
                        else:
                            stim_type = "Flash Off"
                    elif trial_type == "EveryLoom":
                        stim_type = "EveryLoom"
                    start = int(stim)
                    end = int(stim + (post * mean_meta))
                    subset = roi[:, start:end]

                    print(f"{experiment} + {region} + {trial_type} + {stim_type}")
                    ind_min = np.unravel_index(np.nanargmin(subset), subset.shape)
                    min_value = subset[ind_min]
                    channel_min, sample_min = ind_min
                    latency_min = sample_min/fs
            
                    
                    ind_max = np.unravel_index(np.nanargmax(subset), subset.shape)
                    max_value = subset[ind_max]
                    channel_max, sample_max = ind_max
                    latency_max = sample_max/fs
            
                    values = [mouse, Group[mouse], experiment, region, stim_type, channel_min, min_value, latency_min, channel_max, max_value, latency_max]
                    results.append(values)

        

results_df = pd.DataFrame(results, columns = ["Mouse", "Treatment Group", "Experiment", "Region", "Stim", "Channel min", "min", "latency min", "Channel max", "max", "Latency max"])
# Out:
# mouse = 2
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + Void + Flash + Flash On
# Extinction + Void + Flash + Flash Off
# Extinction + RSPd1 + Flash + Flash On
# Extinction + RSPd1 + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + Void + Flash + Flash On
# Retention + Void + Flash + Flash Off
# Retention + RSPd1 + Flash + Flash On
# Retention + RSPd1 + Flash + Flash Off
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + Void + Loom + Loom 1
# Extinction + Void + Loom + Loom 2
# Extinction + Void + Loom + Loom 3
# Extinction + RSPd1 + Loom + Loom 1
# Extinction + RSPd1 + Loom + Loom 2
# Extinction + RSPd1 + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + Void + Loom + Loom 1
# Retention + Void + Loom + Loom 2
# Retention + Void + Loom + Loom 3
# Retention + RSPd1 + Loom + Loom 1
# Retention + RSPd1 + Loom + Loom 2
# Retention + RSPd1 + Loom + Loom 3
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + Void + EveryLoom + EveryLoom
# Extinction + RSPd1 + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + Void + EveryLoom + EveryLoom
# Retention + RSPd1 + EveryLoom + EveryLoom
# mouse = 3
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + Void + Flash + Flash On
# Extinction + Void + Flash + Flash Off
# Extinction + RSPd1 + Flash + Flash On
# Extinction + RSPd1 + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + Void + Flash + Flash On
# Retention + Void + Flash + Flash Off
# Retention + RSPd1 + Flash + Flash On
# Retention + RSPd1 + Flash + Flash Off
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + Void + Loom + Loom 1
# Extinction + Void + Loom + Loom 2
# Extinction + Void + Loom + Loom 3
# Extinction + RSPd1 + Loom + Loom 1
# Extinction + RSPd1 + Loom + Loom 2
# Extinction + RSPd1 + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + Void + Loom + Loom 1
# Retention + Void + Loom + Loom 2
# Retention + Void + Loom + Loom 3
# Retention + RSPd1 + Loom + Loom 1
# Retention + RSPd1 + Loom + Loom 2
# Retention + RSPd1 + Loom + Loom 3
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + Void + EveryLoom + EveryLoom
# Extinction + RSPd1 + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + Void + EveryLoom + EveryLoom
# Retention + RSPd1 + EveryLoom + EveryLoom
# mouse = 4
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + Void + Flash + Flash On
# Extinction + Void + Flash + Flash Off
# Extinction + RSPd1 + Flash + Flash On
# Extinction + RSPd1 + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + Void + Flash + Flash On
# Retention + Void + Flash + Flash Off
# Retention + RSPd1 + Flash + Flash On
# Retention + RSPd1 + Flash + Flash Off
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + Void + Loom + Loom 1
# Extinction + Void + Loom + Loom 2
# Extinction + Void + Loom + Loom 3
# Extinction + RSPd1 + Loom + Loom 1
# Extinction + RSPd1 + Loom + Loom 2
# Extinction + RSPd1 + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + Void + Loom + Loom 1
# Retention + Void + Loom + Loom 2
# Retention + Void + Loom + Loom 3
# Retention + RSPd1 + Loom + Loom 1
# Retention + RSPd1 + Loom + Loom 2
# Retention + RSPd1 + Loom + Loom 3
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + Void + EveryLoom + EveryLoom
# Extinction + RSPd1 + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + Void + EveryLoom + EveryLoom
# Retention + RSPd1 + EveryLoom + EveryLoom
# mouse = 5
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + Void + Flash + Flash On
# Extinction + Void + Flash + Flash Off
# Extinction + RSPd1 + Flash + Flash On
# Extinction + RSPd1 + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + Void + Flash + Flash On
# Retention + Void + Flash + Flash Off
# Retention + RSPd1 + Flash + Flash On
# Retention + RSPd1 + Flash + Flash Off
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + Void + Loom + Loom 1
# Extinction + Void + Loom + Loom 2
# Extinction + Void + Loom + Loom 3
# Extinction + RSPd1 + Loom + Loom 1
# Extinction + RSPd1 + Loom + Loom 2
# Extinction + RSPd1 + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + Void + Loom + Loom 1
# Retention + Void + Loom + Loom 2
# Retention + Void + Loom + Loom 3
# Retention + RSPd1 + Loom + Loom 1
# Retention + RSPd1 + Loom + Loom 2
# Retention + RSPd1 + Loom + Loom 3
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + Void + EveryLoom + EveryLoom
# Extinction + RSPd1 + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + Void + EveryLoom + EveryLoom
# Retention + RSPd1 + EveryLoom + EveryLoom
# mouse = 7
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + RN + Flash + Flash On
# Extinction + RN + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + RN + Flash + Flash On
# Retention + RN + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + RN + Loom + Loom 1
# Extinction + RN + Loom + Loom 2
# Extinction + RN + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + RN + Loom + Loom 1
# Retention + RN + Loom + Loom 2
# Retention + RN + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + RN + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + RN + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# mouse = 8
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + MB + Flash + Flash On
# Extinction + MB + Flash + Flash Off
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + RSPv1 + Flash + Flash On
# Extinction + RSPv1 + Flash + Flash Off
# Extinction + RSPv2/3 + Flash + Flash On
# Extinction + RSPv2/3 + Flash + Flash Off
# Extinction + RSPd2/3 + Flash + Flash On
# Extinction + RSPd2/3 + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + MB + Flash + Flash On
# Retention + MB + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + RSPv1 + Flash + Flash On
# Retention + RSPv1 + Flash + Flash Off
# Retention + RSPv2/3 + Flash + Flash On
# Retention + RSPv2/3 + Flash + Flash Off
# Retention + RSPd2/3 + Flash + Flash On
# Retention + RSPd2/3 + Flash + Flash Off
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + MB + Loom + Loom 1
# Extinction + MB + Loom + Loom 2
# Extinction + MB + Loom + Loom 3
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + RSPv1 + Loom + Loom 1
# Extinction + RSPv1 + Loom + Loom 2
# Extinction + RSPv1 + Loom + Loom 3
# Extinction + RSPv2/3 + Loom + Loom 1
# Extinction + RSPv2/3 + Loom + Loom 2
# Extinction + RSPv2/3 + Loom + Loom 3
# Extinction + RSPd2/3 + Loom + Loom 1
# Extinction + RSPd2/3 + Loom + Loom 2
# Extinction + RSPd2/3 + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + MB + Loom + Loom 1
# Retention + MB + Loom + Loom 2
# Retention + MB + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + RSPv1 + Loom + Loom 1
# Retention + RSPv1 + Loom + Loom 2
# Retention + RSPv1 + Loom + Loom 3
# Retention + RSPv2/3 + Loom + Loom 1
# Retention + RSPv2/3 + Loom + Loom 2
# Retention + RSPv2/3 + Loom + Loom 3
# Retention + RSPd2/3 + Loom + Loom 1
# Retention + RSPd2/3 + Loom + Loom 2
# Retention + RSPd2/3 + Loom + Loom 3
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + MB + EveryLoom + EveryLoom
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + RSPv1 + EveryLoom + EveryLoom
# Extinction + RSPv2/3 + EveryLoom + EveryLoom
# Extinction + RSPd2/3 + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + MB + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + RSPv1 + EveryLoom + EveryLoom
# Retention + RSPv2/3 + EveryLoom + EveryLoom
# Retention + RSPd2/3 + EveryLoom + EveryLoom
# mouse = 9
# Extinction + PAG + Flash + Flash On
# Extinction + PAG + Flash + Flash Off
# Extinction + SCdw + Flash + Flash On
# Extinction + SCdw + Flash + Flash Off
# Extinction + MRN + Flash + Flash On
# Extinction + MRN + Flash + Flash Off
# Extinction + SCdg + Flash + Flash On
# Extinction + SCdg + Flash + Flash Off
# Extinction + SCiw + Flash + Flash On
# Extinction + SCiw + Flash + Flash Off
# Extinction + SCop + Flash + Flash On
# Extinction + SCop + Flash + Flash Off
# Extinction + SCsg + Flash + Flash On
# Extinction + SCsg + Flash + Flash Off
# Extinction + SCig + Flash + Flash On
# Extinction + SCig + Flash + Flash Off
# Extinction + SCzo + Flash + Flash On
# Extinction + SCzo + Flash + Flash Off
# Extinction + Void + Flash + Flash On
# Extinction + Void + Flash + Flash Off
# Extinction + RSPd1 + Flash + Flash On
# Extinction + RSPd1 + Flash + Flash Off
# Retention + PAG + Flash + Flash On
# Retention + PAG + Flash + Flash Off
# Retention + SCdw + Flash + Flash On
# Retention + SCdw + Flash + Flash Off
# Retention + MRN + Flash + Flash On
# Retention + MRN + Flash + Flash Off
# Retention + SCdg + Flash + Flash On
# Retention + SCdg + Flash + Flash Off
# Retention + SCiw + Flash + Flash On
# Retention + SCiw + Flash + Flash Off
# Retention + SCop + Flash + Flash On
# Retention + SCop + Flash + Flash Off
# Retention + SCsg + Flash + Flash On
# Retention + SCsg + Flash + Flash Off
# Retention + SCig + Flash + Flash On
# Retention + SCig + Flash + Flash Off
# Retention + SCzo + Flash + Flash On
# Retention + SCzo + Flash + Flash Off
# Retention + Void + Flash + Flash On
# Retention + Void + Flash + Flash Off
# Retention + RSPd1 + Flash + Flash On
# Retention + RSPd1 + Flash + Flash Off
# Extinction + PAG + Loom + Loom 1
# Extinction + PAG + Loom + Loom 2
# Extinction + PAG + Loom + Loom 3
# Extinction + SCdw + Loom + Loom 1
# Extinction + SCdw + Loom + Loom 2
# Extinction + SCdw + Loom + Loom 3
# Extinction + MRN + Loom + Loom 1
# Extinction + MRN + Loom + Loom 2
# Extinction + MRN + Loom + Loom 3
# Extinction + SCdg + Loom + Loom 1
# Extinction + SCdg + Loom + Loom 2
# Extinction + SCdg + Loom + Loom 3
# Extinction + SCiw + Loom + Loom 1
# Extinction + SCiw + Loom + Loom 2
# Extinction + SCiw + Loom + Loom 3
# Extinction + SCop + Loom + Loom 1
# Extinction + SCop + Loom + Loom 2
# Extinction + SCop + Loom + Loom 3
# Extinction + SCsg + Loom + Loom 1
# Extinction + SCsg + Loom + Loom 2
# Extinction + SCsg + Loom + Loom 3
# Extinction + SCig + Loom + Loom 1
# Extinction + SCig + Loom + Loom 2
# Extinction + SCig + Loom + Loom 3
# Extinction + SCzo + Loom + Loom 1
# Extinction + SCzo + Loom + Loom 2
# Extinction + SCzo + Loom + Loom 3
# Extinction + Void + Loom + Loom 1
# Extinction + Void + Loom + Loom 2
# Extinction + Void + Loom + Loom 3
# Extinction + RSPd1 + Loom + Loom 1
# Extinction + RSPd1 + Loom + Loom 2
# Extinction + RSPd1 + Loom + Loom 3
# Retention + PAG + Loom + Loom 1
# Retention + PAG + Loom + Loom 2
# Retention + PAG + Loom + Loom 3
# Retention + SCdw + Loom + Loom 1
# Retention + SCdw + Loom + Loom 2
# Retention + SCdw + Loom + Loom 3
# Retention + MRN + Loom + Loom 1
# Retention + MRN + Loom + Loom 2
# Retention + MRN + Loom + Loom 3
# Retention + SCdg + Loom + Loom 1
# Retention + SCdg + Loom + Loom 2
# Retention + SCdg + Loom + Loom 3
# Retention + SCiw + Loom + Loom 1
# Retention + SCiw + Loom + Loom 2
# Retention + SCiw + Loom + Loom 3
# Retention + SCop + Loom + Loom 1
# Retention + SCop + Loom + Loom 2
# Retention + SCop + Loom + Loom 3
# Retention + SCsg + Loom + Loom 1
# Retention + SCsg + Loom + Loom 2
# Retention + SCsg + Loom + Loom 3
# Retention + SCig + Loom + Loom 1
# Retention + SCig + Loom + Loom 2
# Retention + SCig + Loom + Loom 3
# Retention + SCzo + Loom + Loom 1
# Retention + SCzo + Loom + Loom 2
# Retention + SCzo + Loom + Loom 3
# Retention + Void + Loom + Loom 1
# Retention + Void + Loom + Loom 2
# Retention + Void + Loom + Loom 3
# Retention + RSPd1 + Loom + Loom 1
# Retention + RSPd1 + Loom + Loom 2
# Retention + RSPd1 + Loom + Loom 3
# Extinction + PAG + EveryLoom + EveryLoom
# Extinction + SCdw + EveryLoom + EveryLoom
# Extinction + MRN + EveryLoom + EveryLoom
# Extinction + SCdg + EveryLoom + EveryLoom
# Extinction + SCiw + EveryLoom + EveryLoom
# Extinction + SCop + EveryLoom + EveryLoom
# Extinction + SCsg + EveryLoom + EveryLoom
# Extinction + SCig + EveryLoom + EveryLoom
# Extinction + SCzo + EveryLoom + EveryLoom
# Extinction + Void + EveryLoom + EveryLoom
# Extinction + RSPd1 + EveryLoom + EveryLoom
# Retention + PAG + EveryLoom + EveryLoom
# Retention + SCdw + EveryLoom + EveryLoom
# Retention + MRN + EveryLoom + EveryLoom
# Retention + SCdg + EveryLoom + EveryLoom
# Retention + SCiw + EveryLoom + EveryLoom
# Retention + SCop + EveryLoom + EveryLoom
# Retention + SCsg + EveryLoom + EveryLoom
# Retention + SCig + EveryLoom + EveryLoom
# Retention + SCzo + EveryLoom + EveryLoom
# Retention + Void + EveryLoom + EveryLoom
# Retention + RSPd1 + EveryLoom + EveryLoom

# %%
results_df
# Out:
#      Mouse Treatment Group  Experiment Region       Stim  Channel min  \
# 0        2         Vehicle  Extinction    PAG   Flash On           80
# 1        2         Vehicle  Extinction    PAG  Flash Off           89
# 2        2         Vehicle  Extinction   SCdw   Flash On            9
# 3        2         Vehicle  Extinction   SCdw  Flash Off           19
# 4        2         Vehicle  Extinction    MRN   Flash On           32
# ..     ...             ...         ...    ...        ...          ...
# 919      9         Vehicle   Retention   SCsg  EveryLoom           26
# 920      9         Vehicle   Retention   SCig  EveryLoom           12
# 921      9         Vehicle   Retention   SCzo  EveryLoom            4
# 922      9         Vehicle   Retention   Void  EveryLoom            3
# 923      9         Vehicle   Retention  RSPd1  EveryLoom            0
#
#            min  latency min  Channel max        max  Latency max
# 0   -14.107041        0.217           13   7.322185        0.243
# 1   -13.004292        0.384           84  10.829033        0.939
# 2    -5.190354        0.581           17   4.588194        0.270
# 3    -4.837134        0.978            4   6.191058        0.684
# 4    -5.902097        0.276            0   4.757235        0.629
# ..         ...          ...          ...        ...          ...
# 919 -16.910833        0.452           39  16.889807        0.351
# 920  -5.539552        0.381            7   9.174429        0.275
# 921 -15.043324        0.022            1  16.596998        0.350
# 922 -15.875078        0.022            0  15.948332        0.351
# 923 -10.952209        0.022            0  13.470645        0.493
#
# [924 rows x 11 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.lines as mlines

# 1. Data Processing Pipeline
plot_df = (
    results_df[results_df["Experiment"].isin(["Extinction", "Retention"])]
    .query("Stim in ['Loom 1', 'Loom 2', 'Loom 3', 'EveryLoom', 'Flash On', 'Flash Off']")
    .assign(Phase_Stim = lambda x: x["Experiment"] + "_" + x["Stim"])
)

stim_order = ["Loom 1", "Loom 2", "Loom 3", "EveryLoom", "Flash On", "Flash Off"]
tick_order = [f"{e}_{s}" for e in ["Extinction", "Retention"] for s in stim_order]
display_labels = ["L1", "L2", "L3", "Avg", "F-On", "F-Off"] * 2

palette_colors = {'Vehicle': '#3498db', 'Psilocybin': '#e74c3c'}
treatment_order = ['Vehicle', 'Psilocybin']

def draw_publishable_phases(data, **kwargs):
    ax = plt.gca()
    
    # 1. DYNAMIC N-CALCULATION
    counts_veh = data[data['Treatment Group'] == 'Vehicle']['Phase_Stim'].value_counts()
    counts_psi = data[data['Treatment Group'] == 'Psilocybin']['Phase_Stim'].value_counts()
    n_veh = counts_veh.max() if not counts_veh.empty else 0
    n_psi = counts_psi.max() if not counts_psi.empty else 0
    
    # 2. PLOT N NUMBERS (Moved slightly up to avoid x-tick collision)
    ax.text(0.03, 0.15, f"n = {n_veh}", color=palette_colors["Vehicle"], transform=ax.transAxes, 
            fontsize=10, fontweight='bold', ha='left')
    ax.text(0.03, 0.06, f"n = {n_psi}", color=palette_colors["Psilocybin"], transform=ax.transAxes, 
            fontsize=10, fontweight='bold', ha='left')
    
    # 3. DRAW THE DATA
    for phase in ["Extinction", "Retention"]:
        phase_data = data[data["Experiment"] == phase]
        
        # Background Raw Data (THE FIX: Reduced size from 5.5 to 4.5 for less clutter)
        sns.stripplot(
            data=phase_data, x="Phase_Stim", y="min", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, alpha=0.50, size=4.5, edgecolor='none', zorder=1, 
            legend=False, ax=ax
        )
        
        discrete_stims = ["EveryLoom", "Flash On", "Flash Off"]
        
        # Foreground 1: Sequential Trials (THE FIX: Reduced markersize/linewidth slightly)
        sns.pointplot(
            data=phase_data[~phase_data["Stim"].isin(discrete_stims)], 
            x="Phase_Stim", y="min", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, markers=['o', 's'], linestyles=['-', '--'], 
            errorbar='se', capsize=0.1, linewidth=1.0, markersize=5, 
            err_kws={'linewidth': 1.0}, zorder=3, legend=False, ax=ax
        )
        
        # Foreground 2: Discrete Points
        sns.pointplot(
            data=phase_data[phase_data["Stim"].isin(discrete_stims)], 
            x="Phase_Stim", y="min", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, markers=['o', 's'], linestyles=['', ''], 
            errorbar='se', capsize=0.1, linewidth=1.0, markersize=5, 
            err_kws={'linewidth': 1.0}, zorder=3, legend=False, ax=ax
        )
        
    # Phase Labels (THE FIX: Moved inside the plot area with a semi-transparent background so they don't clash with facet titles)
    y_pos = 0.96 
    bbox_props = dict(boxstyle="round,pad=0.2", fc="white", ec="none", alpha=0.8)
    
    ax.text(2.5, y_pos, 'EXTINCTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=11, bbox=bbox_props, zorder=5)
    ax.text(8.5, y_pos, 'RETENTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=11, bbox=bbox_props, zorder=5)
    
    # Dividers
    ax.axvline(x=5.5, color='black', linestyle='-', lw=1.2, alpha=0.6, zorder=0)
    ax.axvline(x=2.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=3.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=8.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=9.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 

# 4. INSTANTIATING GRID
sns.set_theme(style="ticks", context="talk")
g = sns.FacetGrid(
    plot_df, 
    col="Region", 
    col_wrap=2, 
    height=5.0,   # slightly reduced height to balance proportions on screen
    aspect=1.6    
)
g.map_dataframe(draw_publishable_phases)

# THE FIX: Increase padding on Seaborn's default Subplot Titles
g.set_titles(col_template="{col_name}", pad=15, fontweight='bold')

# 5. ENFORCING TICK LABELS
for ax in g.axes.flat:
    ax.tick_params(labelbottom=True, labelleft=True, pad=5) # Added padding to tick text
    ax.set_xticks(range(len(display_labels)))
    # THE FIX: Rotate x-labels slightly if they are bleeding into each other horizontally
    ax.set_xticklabels(display_labels, rotation=45, ha='right', rotation_mode='anchor')

# 6. Custom Legend
veh_line = mlines.Line2D([], [], color=palette_colors["Vehicle"], marker='o', linestyle='-', label='Vehicle')
psi_line = mlines.Line2D([], [], color=palette_colors["Psilocybin"], marker='s', linestyle='--', label='Psilocybin')

# THE FIX: Ensure legend is placed relative to the whole figure, not trapped in a squashed corner
g.figure.legend(handles=[veh_line, psi_line], title="Treatment", 
                loc='center left', bbox_to_anchor=(1.0, 0.5), frameon=False)

# --- THE FIX: LAYOUT RECALCULATION ---
# This forces Matplotlib to physically push the subplots apart to accommodate the text sizes
g.tight_layout(w_pad=2.0, h_pad=3.0) 
# -------------------------------------

print("Loom vs Flash nVEP - Spaced and Cleaned")
# Out:
# Loom vs Flash nVEP - Spaced and Cleaned

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.lines as mlines

# 1. Data Processing Pipeline
plot_df = (
    results_df[results_df["Experiment"].isin(["Extinction", "Retention"])]
    .query("Stim in ['Loom 1', 'Loom 2', 'Loom 3', 'EveryLoom', 'Flash On', 'Flash Off']")
    .assign(Phase_Stim = lambda x: x["Experiment"] + "_" + x["Stim"])
)

stim_order = ["Loom 1", "Loom 2", "Loom 3", "EveryLoom", "Flash On", "Flash Off"]
tick_order = [f"{e}_{s}" for e in ["Extinction", "Retention"] for s in stim_order]
display_labels = ["L1", "L2", "L3", "Avg", "F-On", "F-Off"] * 2

palette_colors = {'Vehicle': '#3498db', 'Psilocybin': '#e74c3c'}
treatment_order = ['Vehicle', 'Psilocybin']

def draw_publishable_phases(data, **kwargs):
    ax = plt.gca()
    
    # 1. DYNAMIC N-CALCULATION
    counts_veh = data[data['Treatment Group'] == 'Vehicle']['Phase_Stim'].value_counts()
    counts_psi = data[data['Treatment Group'] == 'Psilocybin']['Phase_Stim'].value_counts()
    n_veh = counts_veh.max() if not counts_veh.empty else 0
    n_psi = counts_psi.max() if not counts_psi.empty else 0
    
    # 2. PLOT N NUMBERS (Moved slightly up to avoid x-tick collision)
    ax.text(0.97, 0.95, f"n = {n_veh}", color=palette_colors["Vehicle"], transform=ax.transAxes, 
            fontsize=10, fontweight='bold', ha='left')
    ax.text(0.97, 0.86, f"n = {n_psi}", color=palette_colors["Psilocybin"], transform=ax.transAxes, 
            fontsize=10, fontweight='bold', ha='left')
    
    # 3. DRAW THE DATA
    for phase in ["Extinction", "Retention"]:
        phase_data = data[data["Experiment"] == phase]
        
        # Background Raw Data (THE FIX: Reduced size from 5.5 to 4.5 for less clutter)
        sns.stripplot(
            data=phase_data, x="Phase_Stim", y="max", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, alpha=0.50, size=4.5, edgecolor='none', zorder=1, 
            legend=False, ax=ax
        )
        
        discrete_stims = ["EveryLoom", "Flash On", "Flash Off"]
        
        # Foreground 1: Sequential Trials (THE FIX: Reduced markersize/linewidth slightly)
        sns.pointplot(
            data=phase_data[~phase_data["Stim"].isin(discrete_stims)], 
            x="Phase_Stim", y="max", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, markers=['o', 's'], linestyles=['-', '--'], 
            errorbar='se', capsize=0.1, linewidth=1.0, markersize=5, 
            err_kws={'linewidth': 1.0}, zorder=3, legend=False, ax=ax
        )
        
        # Foreground 2: Discrete Points
        sns.pointplot(
            data=phase_data[phase_data["Stim"].isin(discrete_stims)], 
            x="Phase_Stim", y="max", hue="Treatment Group", 
            order=tick_order, hue_order=treatment_order, palette=palette_colors, 
            dodge=True, markers=['o', 's'], linestyles=['', ''], 
            errorbar='se', capsize=0.1, linewidth=1.0, markersize=5, 
            err_kws={'linewidth': 1.0}, zorder=3, legend=False, ax=ax
        )
        
    # Phase Labels (THE FIX: Moved inside the plot area with a semi-transparent background so they don't clash with facet titles)
    y_pos = 0.96 
    bbox_props = dict(boxstyle="round,pad=0.2", fc="white", ec="none", alpha=0.8)
    
    ax.text(2.5, y_pos, 'EXTINCTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=11, bbox=bbox_props, zorder=5)
    ax.text(8.5, y_pos, 'RETENTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=11, bbox=bbox_props, zorder=5)
    
    # Dividers
    ax.axvline(x=5.5, color='black', linestyle='-', lw=1.2, alpha=0.6, zorder=0)
    ax.axvline(x=2.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=3.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=8.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=9.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 

# 4. INSTANTIATING GRID
sns.set_theme(style="ticks", context="talk")
g = sns.FacetGrid(
    plot_df, 
    col="Region", 
    col_wrap=2, 
    height=5.0,   # slightly reduced height to balance proportions on screen
    aspect=1.6    
)
g.map_dataframe(draw_publishable_phases)

# THE FIX: Increase padding on Seaborn's default Subplot Titles
g.set_titles(col_template="{col_name}", pad=15, fontweight='bold')

# 5. ENFORCING TICK LABELS
for ax in g.axes.flat:
    ax.tick_params(labelbottom=True, labelleft=True, pad=5) # Added padding to tick text
    ax.set_xticks(range(len(display_labels)))
    # THE FIX: Rotate x-labels slightly if they are bleeding into each other horizontally
    ax.set_xticklabels(display_labels, rotation=45, ha='right', rotation_mode='anchor')

# 6. Custom Legend
veh_line = mlines.Line2D([], [], color=palette_colors["Vehicle"], marker='o', linestyle='-', label='Vehicle')
psi_line = mlines.Line2D([], [], color=palette_colors["Psilocybin"], marker='s', linestyle='--', label='Psilocybin')

# THE FIX: Ensure legend is placed relative to the whole figure, not trapped in a squashed corner
g.figure.legend(handles=[veh_line, psi_line], title="Treatment", 
                loc='center left', bbox_to_anchor=(1.0, 0.5), frameon=False)

# --- THE FIX: LAYOUT RECALCULATION ---
# This forces Matplotlib to physically push the subplots apart to accommodate the text sizes
g.tight_layout(w_pad=2.0, h_pad=3.0) 
# -------------------------------------

print("Loom vs Flash nVEP - Spaced and Cleaned")
# Out:
# Loom vs Flash nVEP - Spaced and Cleaned

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.lines as mlines

# 1. Data Processing Pipeline
plot_df = (
    results_df[results_df["Experiment"].isin(["Extinction", "Retention"])]
    .query("Stim in ['Loom 1', 'Loom 2', 'Loom 3', 'EveryLoom', 'Flash On', 'Flash Off']")
    .assign(Phase_Stim = lambda x: x["Experiment"] + "_" + x["Stim"])
)

stim_order = ["Loom 1", "Loom 2", "Loom 3", "EveryLoom", "Flash On", "Flash Off"]
tick_order = [f"{e}_{s}" for e in ["Extinction", "Retention"] for s in stim_order]
display_labels = ["L1", "L2", "L3", "Avg", "F-On", "F-Off"] * 2

palette_colors = {'Vehicle': '#3498db', 'Psilocybin': '#e74c3c'}
treatment_order = ['Vehicle', 'Psilocybin']

def draw_publishable_phases(data, **kwargs):
    ax = plt.gca()
    
    # 1. DYNAMIC N-CALCULATION
    counts_veh = data[data['Treatment Group'] == 'Vehicle']['Phase_Stim'].value_counts()
    counts_psi = data[data['Treatment Group'] == 'Psilocybin']['Phase_Stim'].value_counts()
    n_veh = counts_veh.max() if not counts_veh.empty else 0
    n_psi = counts_psi.max() if not counts_psi.empty else 0
    
    # 2. PLOT N NUMBERS (Top Right Placement)
    ax.text(0.97, 0.95, f"n = {n_veh}", color=palette_colors["Vehicle"], transform=ax.transAxes, 
            fontsize=16, fontweight='bold', ha='right', va='top', zorder=10)
    ax.text(0.97, 0.86, f"n = {n_psi}", color=palette_colors["Psilocybin"], transform=ax.transAxes, 
            fontsize=16, fontweight='bold', ha='right', va='top', zorder=10)
    
    # 3. DRAW THE DATA (The Overplotting Engine)
    discrete_stims = ["EveryLoom", "Flash On", "Flash Off"]
    
    for phase in ["Extinction", "Retention"]:
        phase_data = data[data["Experiment"] == phase]
        
        # --- THE FIX: NESTED LOOP FOR MULTIPLE METRICS ---
        for metric, m_shape in [("max", "^"), ("min", "v")]:
            
            # Background Raw Data
            sns.stripplot(
                data=phase_data, x="Phase_Stim", y=metric, hue="Treatment Group", 
                order=tick_order, hue_order=treatment_order, palette=palette_colors, 
                dodge=True, alpha=0.35, size=7.0, edgecolor='none', zorder=1, 
                jitter=True, marker=m_shape, legend=False, ax=ax
            )
            
            # Foreground 1: Sequential Trials
            sns.pointplot(
                data=phase_data[~phase_data["Stim"].isin(discrete_stims)], 
                x="Phase_Stim", y=metric, hue="Treatment Group", 
                order=tick_order, hue_order=treatment_order, palette=palette_colors, 
                dodge=True, markers=[m_shape, m_shape], linestyles=['-', '--'], 
                errorbar='se', capsize=0.1, linewidth=3.0, markersize=9, 
                err_kws={'linewidth': 3.0}, zorder=3, legend=False, ax=ax
            )
            
            # Foreground 2: Discrete Points
            sns.pointplot(
                data=phase_data[phase_data["Stim"].isin(discrete_stims)], 
                x="Phase_Stim", y=metric, hue="Treatment Group", 
                order=tick_order, hue_order=treatment_order, palette=palette_colors, 
                dodge=True, markers=[m_shape, m_shape], linestyles=['', ''], 
                errorbar='se', capsize=0.1, linewidth=3.0, markersize=9, 
                err_kws={'linewidth': 3.0}, zorder=3, legend=False, ax=ax
            )
        # -------------------------------------------------
        
    # Phase Labels
    y_pos = 0.96 
    bbox_props = dict(boxstyle="round,pad=0.2", fc="white", ec="none", alpha=0.8)
    
    ax.text(2.5, y_pos, 'EXTINCTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=18, bbox=bbox_props, zorder=5)
    ax.text(8.5, y_pos, 'RETENTION', transform=ax.get_xaxis_transform(), 
            ha='center', va='top', fontweight='bold', fontsize=18, bbox=bbox_props, zorder=5)
    
    # Dividers
    ax.axvline(x=5.5, color='black', linestyle='-', lw=1.2, alpha=0.6, zorder=0)
    ax.axvline(x=2.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=3.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=8.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    ax.axvline(x=9.5, color='gray', linestyle=':', lw=1, alpha=0.5, zorder=0) 
    
    # The Zero Line Reference (Critical for Min/Max scales)
    ax.axhline(y=0, color='black', linestyle='-', lw=0.8, alpha=0.3, zorder=0)

# 4. INSTANTIATING GRID
sns.set_theme(style="ticks", context="talk")
g = sns.FacetGrid(
    plot_df, 
    col="Region", 
    col_wrap=1, 
    height=8.0,   
    aspect=1.6    
)
g.map_dataframe(draw_publishable_phases)
g.set_titles(col_template="{col_name}", pad=15, fontweight='bold')
g.set_axis_labels(x_var="", y_var="Amplitude (µV)", fontsize = 18)

# 5. ENFORCING TICK LABELS
for ax in g.axes.flat:
    ax.tick_params(labelbottom=True, labelleft=True, pad=5) 
    ax.set_xticks(range(len(display_labels)))
    ax.set_xticklabels(display_labels, rotation=45, ha='right', rotation_mode='anchor')

# 6. Custom Legend (Expanded for Multiple Metrics)
veh_line = mlines.Line2D([], [], color=palette_colors["Vehicle"], linestyle='-', label='Vehicle')
psi_line = mlines.Line2D([], [], color=palette_colors["Psilocybin"], linestyle='--', label='Psilocybin')
max_marker = mlines.Line2D([], [], color='gray', marker='^', linestyle='none', markersize=7, label='Max Peak')
min_marker = mlines.Line2D([], [], color='gray', marker='v', linestyle='none', markersize=7, label='Min Peak')

g.figure.legend(handles=[veh_line, psi_line, max_marker, min_marker], title="Treatment & Metric", 
                loc='center left', bbox_to_anchor=(1.0, 0.5), frameon=False)

# 7. LAYOUT RECALCULATION
g.tight_layout(w_pad=2.0, h_pad=3.0) 

print("Loom vs Flash nVEP - Min & Max Overlay")
# Out:
# Loom vs Flash nVEP - Min & Max Overlay
